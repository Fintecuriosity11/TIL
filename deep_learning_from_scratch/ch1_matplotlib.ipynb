# %% [markdown]
# ![대체 텍스트](data:image/png;base64,...)
#
# # 1.8 Matplotlib
# * Matplotlib는 그래프(graph)를 그리는데 쓰이는 라이브러리

# %% [markdown]
# # 1.81 그래프 그리기

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 준비
x = np.arange(0,8,0.2)                                      # 0에서 8까지 0.2 간격으로 생성
y = np.sin(x)

# 그래프 그리기
plt.plot(x,y)
plt.show()

# %% [markdown]
# > 위의 코드에서는 Numpy의 arange 메소드로 [0, 0.2, 0.4, ...., 7.6,7.8]라는 데이터를 생성하여 변수 x에 할당
#
# > 그 다음 줄에서 x의 각 원소에 Numpy의 sin함수인 np.sin()을 적용하여 변수 y에 할당
# > 이제 x와 y를 인수로 plt.plot 메서드를 호출해 그래프를 그리고 마지막으로 plt.show를 호출해 그래프를 화면에 출력 후 끝

# %% [markdown]
# # 1.82 pyplot의 기능

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 준비
x = np.arange(0,8,0.2)                                         # 0에서 8까지 0.2 간격으로 생성
y1 = np.sin(x)
y2 = np.cos(x)

# 그래프 그리기
plt.plot(x, y1, label="sin")
plt.plot(x, y2, linestyle="--", label="cos")                    # cos 함수는 점선으로 그림
plt.xlabel("x")                                                 # x 축 이름 (x-axis)
plt.ylabel("y")                                                 # y 축 이름 (y-axis)
plt.title('sin & cos')                                          # 그래프 제목
plt.legend()                                                    # 범례
plt.show()
